# %%
import pandas as pd
import numpy as np

# %%
ecoregion_data = pd.read_csv('../zweiven-wwpf-eca8354/data/alldata.csv')
profile_data = pd.read_csv('../zweiven-wwpf-eca8354/data/mammal_based_profiles.csv')

# %%
profile_abundance = profile_data['filt.abundances']
profiles = np.asmatrix(profile_data.iloc[:,:len(profile_data.columns)-1])

# %%
forestable_area_init = []
for i,n in enumerate(ecoregion_data['forest_area_2018']):
    forestable_area_init.append(n + 18 * ecoregion_data[kDefType][i])
ecoregion_data['forestable_area_init'] = forestable_area_init
ecoregion_data['forestable_area_init']
# Out:
# 0      1.865459e+09
# 1      5.308435e+09
# 2      2.357107e+09
# 3      6.665760e+09
# 4      1.509606e+11
#            ...
# 485    6.315629e+09
# 486    2.624290e+07
# 487    7.554571e+09
# 488    1.070777e+10
# 489    1.570920e+10
# Name: forestable_area_init, Length: 490, dtype: float64

# %%
ecoregion_data['ae'] = np.exp(np.log(ecoregion_data['plant_spcs']) - kSARExponent * 
                        np.log(ecoregion_data['forestable_area_init']))
# Out:
# C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
ecoregion_data
# Out:
#     eco_code  eco_num    forest_gdp  forest_partial_gdp           systemindex  \
# 0     AA0101        1  7.151583e+07        5.048456e+07  000000000000000000f4
# 1     AA0102        2  5.180362e+08        1.454000e+08  000000000000000000f7
# 2     AA0103        3  1.854590e+09        7.037624e+08  000000000000000000f9
# 3     AA0104        4  2.680741e+08        1.213101e+08  000000000000000000fa
# 4     AA0105        5  3.598280e+10        2.086320e+10  000000000000000000fc
# ..       ...      ...           ...                 ...                   ...
# 485   PA1218       18  1.318802e+10        3.298438e+09  000000000000000001a3
# 486   PA1219       19  1.316558e+09        4.877750e+07  000000000000000000d8
# 487   PA1220       20  1.859158e+10        1.748147e+09  000000000000000000d9
# 488   PA1221       21  1.504575e+11        1.189991e+10  000000000000000000da
# 489   PA1222       22  2.362191e+11        2.401513e+10  000000000000000000db
#
#      cls_code                                         ecode_name  eco_id_u  \
# 0           0     AA0101. Admiralty Islands lowland rain forests     10000
# 1           0  AA0102. Banda Sea Islands moist deciduous forests     10001
# 2           0                  AA0103. Biak-Numfoor rain forests     10002
# 3           0                          AA0104. Buru rain forests     10003
# 4           0         AA0105. Central Range montane rain forests     10004
# ..        ...                                                ...       ...
# 485         0       PA1218. South Appenine mixed montane forests     10666
# 486         0  PA1219. Southeastern Iberian shrubs and woodlands     10667
# 487         0  PA1220. Southern Anatolian montane conifer and...     10668
# 488         0  PA1221. Southwest Iberian Mediterranean sclero...     10669
# 489         0  PA1222. Tyrrhenian-Adriatic Sclerophyllous and...     10670
#
#                                               eco_name eco_notes  ...  \
# 0               Admiralty Islands Lowland Rain Forests       NaN  ...
# 1            Banda Sea Islands Moist Deciduous Forests       NaN  ...
# 2                            Biak-Numfoor Rain Forests       NaN  ...
# 3                                    Buru Rain Forests       NaN  ...
# 4                   Central Range Montane Rain Forests       NaN  ...
# ..                                                 ...       ...  ...
# 485               South Appenine Mixed Montane Forests       NaN  ...
# 486          Southeastern Iberian Shrubs And Woodlands       NaN  ...
# 487  Southern Anatolian Montane Conifer And Deciduo...       NaN  ...
# 488  Southwest Iberian Mediterranean Sclerophyllous...       NaN  ...
# 489  Tyrrhenian-Adriatic Sclerophyllous And Mixed F...       NaN  ...
#
#     dozer_rate_2009_2015 forest_area_2015 protected_forest_area_2015  \
# 0           6.575988e+04     2.001216e+09               3.228501e+07
# 1           1.212787e+06     6.435802e+09               1.047310e+09
# 2           5.776713e+05     2.504919e+09               4.646499e+08
# 3           5.038409e+05     7.880007e+09               6.844289e+07
# 4           2.008953e+07     1.662544e+11               2.407232e+10
# ..                   ...              ...                        ...
# 485         3.576130e+06     9.640385e+09               5.054443e+09
# 486         2.994627e+04     1.341801e+08               4.616656e+07
# 487         1.518952e+07     3.670746e+10               6.521073e+07
# 488         1.998104e+07     3.963325e+10               9.920575e+09
# 489         1.268922e+07     4.594296e+10               1.196624e+10
#
#     dozer_rate_2000_2018 forest_area_2018 protected_forest_area_2018  \
# 0           3.835783e+06     1.796415e+09               2.809382e+07
# 1           1.915174e+07     4.963703e+09               9.536332e+08
# 2           6.143243e+06     2.246529e+09               4.443113e+08
# 3           1.989708e+07     6.307612e+09               6.023468e+07
# 4           1.429511e+08     1.483875e+11               2.194776e+10
# ..                   ...              ...                        ...
# 485         1.154546e+07     6.107811e+09               3.671806e+09
# 486         4.157932e+04     2.549447e+07               2.085428e+07
# 487         3.324177e+07     6.956219e+09               7.006230e+06
# 488         2.115672e+08     6.899562e+09               2.920980e+09
# 489         4.364635e+07     1.492357e+10               5.301263e+09
#
#       GDPperm2 GDPperm2_partial forestable_area_init         ae
# 0     0.039810         0.028103         1.865459e+09  27.981619
# 1     0.104365         0.029293         5.308435e+09  13.620340
# 2     0.825536         0.313267         2.357107e+09  20.026977
# 3     0.042500         0.019232         6.665760e+09  18.436522
# 4     0.242492         0.140599         1.509606e+11  43.580131
# ..         ...              ...                  ...        ...
# 485   2.159205         0.540036         6.315629e+09  23.021625
# 486  51.640917         1.913258         2.624290e+07  13.129786
# 487   2.672656         0.251307         7.554571e+09  42.307565
# 488  21.806810         1.724734         1.070777e+10  25.646820
# 489  15.828598         1.609209         1.570920e+10  30.149709
#
# [490 rows x 56 columns]

# %%
land_setup = ecoregion_data[]
# Out:
# C:\Users\chris\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 0      21.346773
# 1      22.392563
# 2      21.580701
# 3      22.620250
# 4      25.740285
#          ...
# 485    22.566293
# 486    17.082906
# 487    22.745419
# 488    23.094236
# 489    23.477512
# Name: forestable_area_init, Length: 490, dtype: float64
